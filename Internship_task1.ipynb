# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv(r"C:\Users\ADITYA\Desktop\Winsem\DS_Internship_Task_Week-1\EDA-OnlineNewsPopularity\OnlineNewsPopularity.csv")

# %%
df.head()
# Out:
#                                                  url   n_tokens_title  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...               12
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...                9
# 2  http://mashable.com/2013/01/07/apple-40-billio...                9
# 3  http://mashable.com/2013/01/07/astronaut-notre...                9
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/               13
#
#     n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0                219          0.663594                1.0
# 1                255          0.604743                1.0
# 2                211          0.575130                1.0
# 3                531          0.503788                1.0
# 4               1072          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  \
# 0                   0.815385           4                2          1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 38 columns):
# url                               39644 non-null object
#  n_tokens_title                   39644 non-null int64
#  n_tokens_content                 39644 non-null int64
#  n_unique_tokens                  39644 non-null float64
#  n_non_stop_words                 39644 non-null float64
#  n_non_stop_unique_tokens         39644 non-null float64
#  num_hrefs                        39644 non-null int64
#  num_self_hrefs                   39644 non-null int64
#  num_imgs                         39644 non-null int64
#  num_videos                       39644 non-null int64
#  average_token_length             39644 non-null float64
#  num_keywords                     39644 non-null int64
#  data_channel_is_lifestyle        39644 non-null int64
#  data_channel_is_entertainment    39644 non-null int64
#  data_channel_is_bus              39644 non-null int64
# ...

# %%
df.describe()
# Out:
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# count     39644.000000       39644.000000      39644.000000
# mean         10.398749         546.514731          0.548216
# std           2.114037         471.107508          3.520708
# min           2.000000           0.000000          0.000000
# 25%           9.000000         246.000000          0.470870
# 50%          10.000000         409.000000          0.539226
# 75%          12.000000         716.000000          0.608696
# max          23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# min             0.000000                   0.000000      0.000000
# 25%             1.000000                   0.625739      4.000000
# ...

# %%
print(df.isnull()) #//**There are apparently no nulls.**//
# Out:
#          url   n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0      False            False              False             False
# 1      False            False              False             False
# 2      False            False              False             False
# 3      False            False              False             False
# 4      False            False              False             False
# ...      ...              ...                ...               ...
# 39639  False            False              False             False
# 39640  False            False              False             False
# 39641  False            False              False             False
# 39642  False            False              False             False
# 39643  False            False              False             False
#
#         n_non_stop_words   n_non_stop_unique_tokens   num_hrefs  \
# 0                  False                      False       False
# ...

# %%
plt.figure(figsize = (60,50))
plt.title('Share Co-relation', fontsize = 50);

# Mask to remove redundancy from the heatmap.
mask = np.zeros_like(df.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sb.heatmap(df.corr(), mask=mask, vmin=-1, vmax = 1, cmap = "coolwarm",  annot = True);
#plt.savefig('./images/sat_act_heatmap.png')

# %%
cols=pd.DataFrame([df.columns]);
share=pd.DataFrame(df[' shares'])
type(cols);type(share)
# Out:
# pandas.core.frame.DataFrame

# %%
sb.set()
for i in range(1,len(cols)):
    sb.pairplot(df[(cols[i])])
    plt.show()

# %%
df[' shares'].describe()# we see that the max value is way higer and out of range than most of the other values---outlier and so is min
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name:  shares, dtype: float64

# %%
df=df[df[' shares']<10000]
df[' shares'].describe()
# Out:
# count    37429.000000
# mean      2022.382538
# std       1758.059454
# min          1.000000
# 25%        925.000000
# 50%       1400.000000
# 75%       2400.000000
# max       9900.000000
# Name:  shares, dtype: float64

# %%
df.hist(figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024D9DAAD588>,
# ...
#       dtype=object)

# %%
sb.distplot(df[' shares'])# positively skewed guassian distribution of shares on the dataseet

# %%
#df=df.drop('url',axis=1) dropping url column as its a string object type
df.info()
plt.pie(df[' weekday_is_monday'],df[' shares'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37429 entries, 0 to 39643
# Data columns (total 37 columns):
#  n_tokens_title                   37429 non-null int64
#  n_tokens_content                 37429 non-null int64
#  n_unique_tokens                  37429 non-null float64
#  n_non_stop_words                 37429 non-null float64
#  n_non_stop_unique_tokens         37429 non-null float64
#  num_hrefs                        37429 non-null int64
#  num_self_hrefs                   37429 non-null int64
#  num_imgs                         37429 non-null int64
#  num_videos                       37429 non-null int64
#  average_token_length             37429 non-null float64
#  num_keywords                     37429 non-null int64
#  data_channel_is_lifestyle        37429 non-null int64
#  data_channel_is_entertainment    37429 non-null int64
#  data_channel_is_bus              37429 non-null int64
#  data_channel_is_socmed           37429 non-null int64
# ...

# %%
plt.scatter(df[' weekday_is_monday'],df[' shares']) # as pie charting throws an error saying to many values
